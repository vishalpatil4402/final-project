# %%
import pandas as pd
Url = 'https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv'

# %%
data= pd.read_csv(Url)

# %%
data
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# #  High Level Data Understanding:

# %%
#a. Find no. of rows & columns in the dataset

rows = data.shape[0]
cols= data.shape[1]
print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
# Out:
# Number of Rows:  57394
# Number of Columns:  49

# %%
#b. Data types of columns.

data.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %%
#c. Info & describe of data in dataframe.

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
# ...

# %%
data.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.375800e+04   56465.000000        55652.000000  4.436800e+04
# mean   1.677974e+05    1953.576941         1920.431953  6.858639e+03
# std    1.693038e+06   18269.650340        17777.391785  5.578081e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.800000e+02       0.000000            0.857000  1.300000e+01
# 50%    2.070000e+03      14.000000           19.429000  8.400000e+01
# 75%    2.235675e+04     235.000000          245.286000  7.270000e+02
# max    5.515465e+07  646281.000000       584981.857000  1.328537e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  56465.000000         55652.000000             53471.000000
# mean      47.054317            46.835439              3139.099982
# std      390.853776           378.272794              6183.455260
# min    -1918.000000          -232.143000                 0.001000
# ...

# %% [markdown]
# #  Low Level Data Understanding :

# %%
#a. Find count of unique values in location column.

n = len(pd.unique(data['location']))
n
# Out:
# 216

# %%
#b. Find which continent has maximum frequency using values counts.

data['continent'].value_counts().idxmax()
# Out:
# 'Europe'

# %%
# c. Find maximum & mean value in 'total_cases'

data['total_cases'].max()
# Out:
# 55154651.0

# %%
data['total_cases'].mean()
# Out:
# 167797.3688753302

# %%
#  d. Find 25%,50% & 75% quartile value in 'total_deaths'.

print("Quartile value of 25% of total deaths: \n",data["total_deaths"].quantile(0.25),"\n")

print("Quartile value of 50% of total deaths: \n",data["total_deaths"].quantile(0.5),"\n")

print("Quartile value of 75% of total deaths : \n",data["total_deaths"].quantile(0.75),"\n")
# Out:
# Quartile value of 25% of total deaths:
#  13.0
#
# Quartile value of 50% of total deaths:
#  84.0
#
# Quartile value of 75% of total deaths :
#  727.0

# %%
# e. Find which continent has maximum 'human_development_index'.

data[data['human_development_index']==data['human_development_index'].max()][['continent','human_development_index']].head(1)
# Out:
#       continent  human_development_index
# 38632    Europe                    0.953

# %%
# f. Find which continent has minimum 'gdp_per_capita'.

data[data['gdp_per_capita']==data['gdp_per_capita'].min()][['continent','gdp_per_capita']].head(1)
# Out:
#       continent  gdp_per_capita
# 10259    Africa          661.24

# %% [markdown]
# # Filter the dataframe

# %%
#Filter the dataframe with only this columns ['continent','location','date','total_cases','total_deaths','gdp_per_
# capita','human_development_index']and update the data frame.

df=data.filter(['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'])
df
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# # Data Cleaning

# %%
#  a. Remove all duplicates observations

df=df.drop_duplicates()
df.reset_index(drop=True,inplace=True)
df
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %%
# Find missing values in all columns

df.isna().sum()
# Out:
# continent                    646
# location                       0
# date                           0
# total_cases                 3636
# total_deaths               13026
# gdp_per_capita              7027
# human_development_index     8147
# dtype: int64

# %%
# c. Remove all observations where continent column value is missing
# Tip : using subset parameter in dropna

df.dropna(subset = ['continent'])
# Out:
#       continent     location      date  total_cases  total_deaths  \
# 0          Asia  Afghanistan  31/12/19          NaN           NaN
# 1          Asia  Afghanistan  01/01/20          NaN           NaN
# 2          Asia  Afghanistan  02/01/20          NaN           NaN
# 3          Asia  Afghanistan  03/01/20          NaN           NaN
# 4          Asia  Afghanistan  04/01/20          NaN           NaN
# ...         ...          ...       ...          ...           ...
# 56743    Africa     Zimbabwe  13/11/20       8696.0         255.0
# 56744    Africa     Zimbabwe  14/11/20       8765.0         257.0
# 56745    Africa     Zimbabwe  15/11/20       8786.0         257.0
# 56746    Africa     Zimbabwe  16/11/20       8786.0         257.0
# 56747    Africa     Zimbabwe  17/11/20       8897.0         257.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %%
# d. Fill all missing values with 0

df=df.fillna(0)
df
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          0.0           0.0
# 1          Asia    Afghanistan  01/01/20          0.0           0.0
# 2          Asia    Afghanistan  02/01/20          0.0           0.0
# 3          Asia    Afghanistan  03/01/20          0.0           0.0
# 4          Asia    Afghanistan  04/01/20          0.0           0.0
# ...         ...            ...       ...          ...           ...
# 57389         0  International  13/11/20        696.0           7.0
# 57390         0  International  14/11/20        696.0           7.0
# 57391         0  International  15/11/20        696.0           7.0
# 57392         0  International  16/11/20        696.0           7.0
# 57393         0  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# #  Date time format :

# %%
# a. Convert date column in datetime format using pandas.to_datetime

df['date'] = pd.to_datetime(df['date'])
df
# Out:
#       continent       location       date  total_cases  total_deaths  \
# 0          Asia    Afghanistan 2019-12-31          0.0           0.0
# 1          Asia    Afghanistan 2020-01-01          0.0           0.0
# 2          Asia    Afghanistan 2020-02-01          0.0           0.0
# 3          Asia    Afghanistan 2020-03-01          0.0           0.0
# 4          Asia    Afghanistan 2020-04-01          0.0           0.0
# ...         ...            ...        ...          ...           ...
# 57389         0  International 2020-11-13        696.0           7.0
# 57390         0  International 2020-11-14        696.0           7.0
# 57391         0  International 2020-11-15        696.0           7.0
# 57392         0  International 2020-11-16        696.0           7.0
# 57393         0  International 2020-11-17        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# ...

# %%
# Create new column month after extracting month data from date column

df['month'] = pd.DatetimeIndex(df['date']).month
df
# Out:
#       continent       location       date  total_cases  total_deaths  \
# 0          Asia    Afghanistan 2019-12-31          0.0           0.0
# 1          Asia    Afghanistan 2020-01-01          0.0           0.0
# 2          Asia    Afghanistan 2020-02-01          0.0           0.0
# 3          Asia    Afghanistan 2020-03-01          0.0           0.0
# 4          Asia    Afghanistan 2020-04-01          0.0           0.0
# ...         ...            ...        ...          ...           ...
# 57389         0  International 2020-11-13        696.0           7.0
# 57390         0  International 2020-11-14        696.0           7.0
# 57391         0  International 2020-11-15        696.0           7.0
# 57392         0  International 2020-11-16        696.0           7.0
# 57393         0  International 2020-11-17        696.0           7.0
#
#        gdp_per_capita  human_development_index  month
# 0            1803.987                    0.498     12
# ...

# %% [markdown]
# # Data Aggregation:

# %%
# Find max value in all columns using groupby function on 'continent' column
# Tip: use reset_index() after applying groupby

df1= df.groupby('continent').max().reset_index()
df1
# Out:
#        continent                      location       date  total_cases  \
# 0              0                         World 2020-12-11   55154651.0
# 1         Africa                      Zimbabwe 2020-12-11     752269.0
# 2           Asia                         Yemen 2020-12-11    8874290.0
# 3         Europe                       Vatican 2020-12-11    1991233.0
# 4  North America  United States Virgin Islands 2020-12-11   11205486.0
# 5        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 6  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index  month
# 0     1328537.0       15469.207                    0.000     12
# 1       20314.0       26382.287                    0.797     12
# 2      130519.0      116935.600                    0.933     12
# 3       52147.0       94277.965                    0.953     12
# 4      247220.0       54225.446                    0.926     12
# ...

# %%
#  b. Store the result in a new dataframe named 'df_groupby'.
# (Use df_groupby dataframe for all further analysis)

df_groupby = pd.DataFrame(df1)
df_groupby
# Out:
#        continent                      location       date  total_cases  \
# 0              0                         World 2020-12-11   55154651.0
# 1         Africa                      Zimbabwe 2020-12-11     752269.0
# 2           Asia                         Yemen 2020-12-11    8874290.0
# 3         Europe                       Vatican 2020-12-11    1991233.0
# 4  North America  United States Virgin Islands 2020-12-11   11205486.0
# 5        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 6  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index  month
# 0     1328537.0       15469.207                    0.000     12
# 1       20314.0       26382.287                    0.797     12
# 2      130519.0      116935.600                    0.933     12
# 3       52147.0       94277.965                    0.953     12
# 4      247220.0       54225.446                    0.926     12
# ...

# %% [markdown]
# # Feature Engineering :

# %%
#  a. Create a new feature 'total_deaths_to_total_cases' by ratio of'total_deaths' column to 'total_cases'

df_groupby['total_deaths_to_total_cases'] = (df_groupby['total_deaths']/df_groupby['total_cases'])
df_groupby
# Out:
#        continent                      location       date  total_cases  \
# 0              0                         World 2020-12-11   55154651.0
# 1         Africa                      Zimbabwe 2020-12-11     752269.0
# 2           Asia                         Yemen 2020-12-11    8874290.0
# 3         Europe                       Vatican 2020-12-11    1991233.0
# 4  North America  United States Virgin Islands 2020-12-11   11205486.0
# 5        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 6  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index  month  \
# 0     1328537.0       15469.207                    0.000     12
# 1       20314.0       26382.287                    0.797     12
# 2      130519.0      116935.600                    0.933     12
# 3       52147.0       94277.965                    0.953     12
# 4      247220.0       54225.446                    0.926     12
# ...

# %% [markdown]
# # Data Visualization :

# %%
# a. Perform Univariate analysis on 'gdp_per_capita' column by plotting histogram using seaborn dist plot.

import seaborn as sns
sns.distplot(df_groupby['gdp_per_capita'], hist=True)
# Out:
# C:\Users\Sachin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='gdp_per_capita', ylabel='Density'>

# %%
# b. Plot a scatter plot of 'total_cases' & 'gdp_per_capita'

ax = df_groupby.plot.scatter(x="total_cases", y="gdp_per_capita")
ax
# Out:
# <AxesSubplot:xlabel='total_cases', ylabel='gdp_per_capita'>

# %%
# Plot Pairplot on df_groupby dataset.

sns.pairplot(df_groupby)

# %%
# Plot a bar plot of 'continent' column with 'total_cases' .
# Tip : using kind='bar' in seaborn catplot

sns.barplot(x = "continent",y = "total_cases",data= df_groupby)
# Out:
# <AxesSubplot:xlabel='continent', ylabel='total_cases'>

# %%
ax= sns.catplot(x='continent', y='total_cases',kind='bar',data=df_groupby)
ax

# %%
# Save the df_groupby dataframe in your local drive using pandas.to_csv function .

df_groupby.to_csv("df_groupby2.csv")
